# %%
print ("hello word")
print ("saya shintya")
print ("jurusan TI-MDI")
# Out:
# hello word
# saya shintya
# jurusan TI-MDI

# %%
print ("=======MENGHITUNG LUAS DAN KELILING PERSEGI PANJANG========")
p = int(input("Masukan Panjang ="))
l = int(input("Masukan Lebar ="))

L = p*l
K = 2*(p+l)

print("Luas Persegi Panjang adalah =", L)
print("Keliling persegi panjang adalah =", K)
# Out:
# =======MENGHITUNG LUAS DAN KELILING PERSEGI PANJANG========
# Masukan Panjang =12
# Masukan Lebar =14
# Luas Persegi Panjang adalah = 168
# Keliling persegi panjang adalah = 52

# %%
print("Menghitung volume kubus")
#untuk input jumlah sisi
S = int(input("Masukan jumlah sisi ="))
#rumus sisi
V = S*S*S
#output
print ("Volume kubus adalah =", V)
# Out:
# Menghitung volume kubus
# Masukan jumlah sisi =3
# Volume kubus adalah = 27

# %%
A = int(input("Angka Pertama ="))
B = int(input("Angka Kedua ="))

C = A+B

print ("Total =", C)
# Out:
# Angka Pertama =1
# Angka Kedua =2
# Total = 3
