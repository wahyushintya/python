# %%
## String

Nama ="Ni Putu Wahyu Shintya Dewi"
print (Nama)
# Out:
# Ni Putu Wahyu Shintya Dewi

# %%
#Slice untuk mengambil nilai
name = 'belajar python'
print ("name[0]: ", name[0])
print ("name[0:3]: ", name[0:3])
print (name[1:4])
# Out:
# name[0]:  b
# name[0:3]:  bel
# ela

# %%
pesan = " hai dunia"
print ("update string - ", pesan[:8]+ "Python")
# Out:
# update string -   hai dunPython

# %%
a = "saya" + "5"
print (a)
# Out:
# saya5

# %%
var = "saya sedang belajar python"
print("var [0]", var [2])
# Out:
# var [0] y

# %%
a = "saya " *5
print (a)
# Out:
# saya saya saya saya saya

# %%
#Len tipe data string yg digunakan untuk menghitung jumlah dalam variable
a = ("saya belajar python")
print (len(a))
# Out:
# 19

# %%
var1 = ("Nama saya kristina ") * 5
var2 = "nama saya siapa"

print (var1)
# Out:
#  /n Nama saya kristina  /n Nama saya kristina  /n Nama saya kristina  /n Nama saya kristina  /n Nama saya kristina

# %%
var1= "Nama saya" + "Sin"
var2= "Nama" + "saya"

a = "\nnama saya sin" *5
print (a)
# Out:
# nama saya sin
# nama saya sin
# nama saya sin
# nama saya sin
# nama saya sin

# %%
var1= "Nama Saya"
var2= "Sehin"
print(var1,var2)
print ((var1 + " " + var2 + '\n') * 10)
print(len(var1 + var2))
# Out:
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
# Nama Saya Sehin
#
# 14

# %%
a = str(input("Nama saya : "))
b = int(input("Masukan indeks yg dicari : "))
print("Jumlah karakter nama saya adalah : " ,len(a))
print("huruf yg ada pada index ke", b ,"adalah :", a[b])
# Out:
# Nama saya : sehinnnnnnnnnnnnnnnnnnn
# Masukan indeks yg dicari : 5
# Jumlah karakter nama saya adalah :  23
# huruf yg ada pada index ke 5 adalah : n
