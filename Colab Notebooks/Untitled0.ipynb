# %%
#LIST

nama_mahasiswa = ["agus", "Budi","Caca","Mega","Nia"]
print(nama_mahasiswa[2], "love",nama_mahasiswa[4] )
# Out:
# Caca love Nia

# %%
#dictionary
NAMA_MAHASISWA = {
'nm_mhs1' :'agus',
'nm_mhs2' :'Budi',
'nm_mhs3' :'caca',
'nm_mhs4' :'mega',
'nm_mhs5' :'nia'
}
print ("mahasiswa : ", NAMA_MAHASISWA["nm_mhs3"], "dan" , NAMA_MAHASISWA['nm_mhs5'])
# Out:
# mahasiswa :  caca dan nia

# %%
#INPUTOUTPUT
Nama = input("Masukan Nama Anda : ")
Alamat = input("Masukan Alamat : ")
Prodi = input("Masukan Prodi : ")
NIM = int(input("Masukan NIM :"))
print ("nama saya adalah ", Nama,"dari", Alamat, " dengan prodi", Prodi, "dan NIM", NIM )
# Out:
# Masukan Nama Anda : sehin
# Masukan Alamat : dps selatan
# Masukan Prodi : ti
# Masukan NIM :2301010136
# nama saya adalah  sehin dari dps selatan  dengan prodi ti dan NIM 2301010136

# %%
#INPUTOUTPUT
P = int(input("masukan panjang :"))
l = int(input("Masukan Lebar :"))

Luas = P*l
Keliling = 2*(P+l)

print ("Luas persegi panjang adalah :", Luas, "cm")
print ("Keliling persegi panjang adalah : ", Keliling, "cm")
# Out:
# masukan panjang :10
# Masukan Lebar :5
# Luas persegi panjang adalah : 50 cm
# Keliling persegi panjang adalah :  30 cm

# %%
#boolean
print (10>9)
print (9>10)
# Out:
# True
# False

# %%
#boolean2
a = 4000
b = 4000

if a > b :
  print (" a lebih besar dari b")
if a==b :
  print ("a sama dengan b ")
else :
  print (" a tidak lebih besar dari b")
# Out:
# a sama dengan b

# %%
#menghitung luas lapangan

s = int(input ("masukan sisi persegi : "))
r = int(input("Masukan jari jari setling : "))
L = s*s

Luas_Setling = 1/2 * 3.14 * r * r

Luas = L + Luas_Setling

print ("Luas Lapangan adalah : ", Luas)
# Out:
# masukan sisi persegi : 10
# Masukan jari jari setling : 5
# Luas Lapangan adalah :  139.25
