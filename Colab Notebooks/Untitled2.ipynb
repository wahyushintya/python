# %%
a = 12
b = 45

print (bin(a))
print (bin(b))
# Out:
# 0b1100
# 0b101101

# %%
(100-64)/6+20
# Out:
# 26.0

# %%
harga = 2500
jumlah = int(input("Masukan jumlah pensil = "))
diskon = int(input("Masukan diskon = "))
total = jumlah * harga
total_diskon = diskon/100 * total
total_akhir = total - total_diskon
print("totalnya adalah :", total_akhir)
# Out:
# Masukan jumlah pensil = 20
# Masukan diskon = 10
# totalnya adalah : 45000.0

# %%
harga_bakso = 5000

jumlah = int(input("Masukan jumlah = "))
diskon = int(input("Masukan diskon = "))
total = jumlah * harga_bakso
total_diskon = diskon/100 * total
total_akhir = total - total_diskon
print("totalnya adalah :", total_akhir)
# Out:
# Masukan jumlah = 20
# Masukan diskon = 15
# totalnya adalah : 85000.0

# %%
pulpen = 3000
pensil = 5000

barang = int(input(" Masukan Nama barang : "))
jumlah = int (input (" Masukan total pembelian : "))

# %%
print("~~~~~~~~")
pembeli = input("Masukkan nama Pembeli: ")
print ("Nama Pembeli :", pembeli)

def kasir():
    # masukan input dari user
    nama_barang = input('masukan pesanan anda: ')
    harga = int(input('masukan harga barang: '))
    jumlah_beli = int(input('masukan jumlah barang yang anda beli: '))

    # mengitung jumlah harga
    total = harga * jumlah_beli

    # cetak total harga
    print(f'harga total: {nama_barang}, = {total}')

    # input pembayaran dari user
    bayar = int(input('masukan pembayaran: '))

    # mengecek apakah pembayaran kurang atau ada kembalian
    kurang = total - bayar
    kembalian = bayar - total

    if bayar > total:
        print(f'jumlah kembalian anda adalah {kembalian}')
        tanya()

    elif bayar == total:
        print('uang anda pas, terimakasih telah berbelanja ')

    else:
        print(f'maaf uang anda tidak cukup, uang anda kurang {kurang}')
        counter_kasir()
# Out:
# ~~~~~~~~
# Masukkan nama Pembeli: sintia
# Nama Pembeli : sintia
